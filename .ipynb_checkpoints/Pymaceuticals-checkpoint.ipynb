# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# Null hypothesis - Capomulin has no discernible effect on the developing SCC tumors, when looking at the continuous dependent variables, compared to other treatment regimens.
#
# Alternate hypothesis - Capomulin has a discernible effect on SCC tumors, when looking at continuous dependent variables, compared to other treatments.
#
# The study began with 249 mice, all with squamous cell carcinoma tumors at tumor volume of 45 mm3. Findings for one mouse had to be eliminated due to duplicated results.
#
# Treatment regimens included the following:
# Capomulin
# Ceftamin
# Infubinol
# Ketapril
# Naftisol
# Propriva
# Ramicane
# Stelasyn
# Zoniferol
# placebo
#
#
# Of note:
# *Seven mice made it to day 45 with no appearance of metastatic sites. Six of seven of the mice showed a decrease in tumor volume, three on Capomulin and three on Ramicane.
#
# *Five mice made it to day 45 with a decrease in tumor volume to less than 30 mm3. three of these were Ramicane and two on Capomulin.
#
#
# The weight of the mice stayed consistent regardless of the development of the tumors. Smaller mice (<25g) showed better results. The top performers were Capomulin and Ramicane, however, the heaviest mice at the beginning of the study (>25g) were placed on other regimens. I recommend a thorough study using mice of a greater range of sizes on each treatment regimen.
#
# A single mouse (g316) on Capomulin was pulled from the dataframe for a closer look. At 22 months, 22 g, she is one of the older mice in the study. Tumor volume dropped slightly to 44.02275246 at the 5 day check, increased to 45.56582103 at day 40, before dropping for the last five days of the study to 40.1592203. Despite two metastatic sites by the end of the study, data suggests that tumor volume will continue to decrease. I would like to see more long-term studies to gauge the result of prolonged use on the regimen.
#
# After isolating the Capomulin data from the original cleaned dataframe, the remaining value shows a correlation coefficient of 0.84 for the weight of the mice - the independent variable - on Capomulin and the tumor volume - dependent variable - for the mice on Capomulin.
#
# These findings suggest that the treatment is less effective on heavier mice. However, they still show a decrease in tumor volume, suggesting that the null hypothesis be rejected.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)


study_results
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        b128          0           45.000000                 0
# 1        f932          0           45.000000                 0
# 2        g107          0           45.000000                 0
# 3        a457          0           45.000000                 0
# 4        c819          0           45.000000                 0
# ...       ...        ...                 ...               ...
# 1888     r944         45           41.581521                 2
# 1889     u364         45           31.023923                 3
# 1890     p438         45           61.433892                 1
# 1891     x773         45           58.634971                 4
# 1892     b879         45           72.555239                 2
#
# [1893 rows x 4 columns]

# %%
# Combine the data into a single DataFrame
pymaceuticals_data_complete_df = pd.merge(study_results, mouse_metadata, on=["Mouse ID"])


# Display the data table for preview
pymaceuticals_data_complete_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice.
mouse_count = pymaceuticals_data_complete_df["Mouse ID"].nunique()
mouse_count
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

mouse_duplicate_columns = ["Mouse ID", "Timepoint"]
dupe_row_s = pymaceuticals_data_complete_df.duplicated(subset=mouse_duplicate_columns, keep=False)
duplicate_mice = pymaceuticals_data_complete_df[dupe_row_s]["Mouse ID"].unique()

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mice
# Out:
# array(['g989'], dtype=object)

# %%
duplicate_mouse = pymaceuticals_data_complete_df.loc[pymaceuticals_data_complete_df["Mouse ID"]== "g989"]
duplicate_mouse
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0           45.000000                 0     Propriva
# 861     g989          0           45.000000                 0     Propriva
# 862     g989          5           48.786801                 0     Propriva
# 863     g989          5           47.570392                 0     Propriva
# 864     g989         10           51.745156                 0     Propriva
# 865     g989         10           49.880528                 0     Propriva
# 866     g989         15           51.325852                 1     Propriva
# 867     g989         15           53.442020                 0     Propriva
# 868     g989         20           55.326122                 1     Propriva
# 869     g989         20           54.657650                 1     Propriva
# 870     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
duplicates_dropped_df = pymaceuticals_data_complete_df[pymaceuticals_data_complete_df["Mouse ID"].isin(duplicate_mice)==False]
duplicates_dropped_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
mouse_count = duplicates_dropped_df["Mouse ID"].nunique()
mouse_count
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.

tumor_volume_avg = duplicates_dropped_df.groupby(["Drug Regimen"]).mean()["Tumor Volume (mm3)"]
tumor_volume_avg
# Out:
# Drug Regimen
# Capomulin    40.675741
# Ceftamin     52.591172
# Infubinol    52.884795
# Ketapril     55.235638
# Naftisol     54.331565
# Placebo      54.033581
# Propriva     52.320930
# Ramicane     40.216745
# Stelasyn     54.233149
# Zoniferol    53.236507
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Use groupby and summary statistical methods to calculate the median, 

tumor_volume_median = duplicates_dropped_df.groupby(["Drug Regimen"]).median()["Tumor Volume (mm3)"]
tumor_volume_median
# Out:
# Drug Regimen
# Capomulin    41.557809
# Ceftamin     51.776157
# Infubinol    51.820584
# Ketapril     53.698743
# Naftisol     52.509285
# Placebo      52.288934
# Propriva     50.446266
# Ramicane     40.673236
# Stelasyn     52.431737
# Zoniferol    51.818479
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Use groupby and summary statistical methods to calculate the variance

tumor_volume_variance = duplicates_dropped_df.groupby(["Drug Regimen"]).var()["Tumor Volume (mm3)"]
tumor_volume_variance
# Out:
# Drug Regimen
# Capomulin    24.947764
# Ceftamin     39.290177
# Infubinol    43.128684
# Ketapril     68.553577
# Naftisol     66.173479
# Placebo      61.168083
# Propriva     43.852013
# Ramicane     23.486704
# Stelasyn     59.450562
# Zoniferol    48.533355
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Use groupby and summary statistical methods to calculate the standard deviation, 

tumor_volume_stdeviation = duplicates_dropped_df.groupby(["Drug Regimen"]).std()["Tumor Volume (mm3)"]
tumor_volume_stdeviation
# Out:
# Drug Regimen
# Capomulin    4.994774
# Ceftamin     6.268188
# Infubinol    6.567243
# Ketapril     8.279709
# Naftisol     8.134708
# Placebo      7.821003
# Propriva     6.622085
# Ramicane     4.846308
# Stelasyn     7.710419
# Zoniferol    6.966589
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Use groupby and summary statistical methods to calculate the SEM of the tumor volume. 


tumor_volume_SEM = duplicates_dropped_df.groupby(["Drug Regimen"]).sem()["Tumor Volume (mm3)"]
tumor_volume_SEM
# Out:
# Drug Regimen
# Capomulin    0.329346
# Ceftamin     0.469821
# Infubinol    0.492236
# Ketapril     0.603860
# Naftisol     0.596466
# Placebo      0.581331
# Propriva     0.544332
# Ramicane     0.320955
# Stelasyn     0.573111
# Zoniferol    0.516398
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Assemble the resulting series into a single summary DataFrame.

single_summary_data = pd.DataFrame({"Mean Tumor Volume":tumor_volume_avg, "Median Tumor Volume":tumor_volume_median, "Tumor Volume Variance":tumor_volume_variance, "Tumor Volume Std. Dev.":tumor_volume_stdeviation,"Tumor Volume SEM" :tumor_volume_SEM})
single_summary_data
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume SEM
# Drug Regimen
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.

mouse_timepoints = duplicates_dropped_df.groupby(["Drug Regimen"])["Timepoint"].count()

x = duplicates_dropped_df["Drug Regimen"]
y = duplicates_dropped_df["Timepoint"]

bar_plot_pandas = mouse_timepoints.sort_values(ascending=False).plot.bar(color = "blue")
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")
plt.title("Mice Per Drug Treatment")
plt.show()

# %%
mouse_timepoints.sort_values(ascending=False)
# Out:
# Drug Regimen
# Capomulin    230
# Ramicane     228
# Ketapril     188
# Naftisol     186
# Zoniferol    182
# Placebo      181
# Stelasyn     181
# Ceftamin     178
# Infubinol    178
# Propriva     148
# Name: Timepoint, dtype: int64

# %%
# Generate a bar plot showing the total number of rows 
#(Mouse ID/Timepoints) for each drug regimen using pyplot.

mouse_tp_order = mouse_timepoints.sort_values(ascending=False)
plt.bar(mouse_tp_order.index, mouse_tp_order.values, color='blue')
plt.xticks(rotation=90)
plt.xlabel('Drug Regimen')
plt.ylabel('# of Observed Mouse Timepoints')
plt.title('Mice Per Drug Treatment')
plt.show()

# %%
mouse_count = duplicates_dropped_df["Mouse ID"].nunique()
mouse_count
# Out:
# 248

# %%
mouse_sex = duplicates_dropped_df["Sex"].value_counts()
mouse_sex
# Out:
# Male      958
# Female    922
# Name: Sex, dtype: int64

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

mouse_pie = mouse_sex.plot.pie(y='Sex', title='Distribution of Female vs Male', legend=False, autopct='%1.1f%%', shadow=True, startangle=0)

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

labels= ['Male', 'Female']

colors=['blue','orange']

sizes= [958, 922]

plt.pie(sizes,labels=labels, colors=colors, startangle=0, autopct='%1.1f%%')

plt.title('Distribution of Female vs Male')
plt.ylabel('Sex')

plt.axis('equal')

plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
mouse_timepoints[-1]
# Out:
# 182

# %%
print(pd.unique(duplicates_dropped_df['Mouse ID']))
# Out:
# ['b128' 'f932' 'g107' 'a457' 'c819' 'h246' 'p189' 'n923' 'q119' 'f993'
#  'z234' 'b559' 'y260' 'x930' 'o725' 'z969' 'v835' 'r604' 'n304' 'l700'
#  'x336' 'l725' 'm133' 'v295' 'a818' 'y601' 't724' 'k382' 'w422' 'c326'
#  'c139' 'v339' 'a577' 'y163' 'k483' 'k804' 'o809' 'z581' 'a251' 'i386'
#  'c580' 'q132' 'u327' 'v603' 'f278' 'g497' 'd474' 'o973' 'c832' 'o331'
#  'm650' 'v289' 'm550' 'h428' 'r701' 'v199' 'x264' 'f234' 'c458' 'q610'
#  'j913' 'a411' 'a444' 'd251' 'j989' 'y449' 'k403' 'c758' 'x402' 'r811'
#  'a644' 'i177' 'g791' 'a520' 'u196' 'm546' 'w678' 'n364' 's508' 'e662'
#  'z578' 'r921' 'a492' 'w540' 'v764' 'z795' 'e291' 'e584' 'e213' 'j755'
#  's565' 'a366' 'p387' 'b879' 'i901' 'k862' 'g867' 's619' 'w697' 'j984'
#  'c402' 'h333' 'k510' 'p981' 't451' 'a963' 'm269' 'z314' 'o848' 'v719'
#  'q597' 'c895' 'a203' 'f394' 'c264' 'n967' 'f545' 'k894' 'k754' 'g296'
#  'd164' 'w575' 'x613' 'q633' 'b313' 'f129' 'j365' 'p136' 'c559' 'a788'
# ...

# %%
max_timepoints = duplicates_dropped_df.groupby(['Mouse ID'])['Timepoint'].max().reset_index()
max_timepoints
# Out:
#     Mouse ID  Timepoint
# 0       a203         45
# 1       a251         45
# 2       a262         45
# 3       a275         45
# 4       a366         30
# ..       ...        ...
# 243     z435         10
# 244     z578         45
# 245     z581         45
# 246     z795         45
# 247     z969         45
#
# [248 rows x 2 columns]

# %%
max_per_treatment_df = max_timepoints.merge(duplicates_dropped_df)
max_per_treatment_df
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       a203         45           67.973419                 2    Infubinol
# 1       a251         45           65.525743                 1    Infubinol
# 2       a262         45           70.717621                 4      Placebo
# 3       a275         45           62.999356                 3     Ceftamin
# 4       a366         30           63.440686                 1     Stelasyn
# ..       ...        ...                 ...               ...          ...
# 243     z435         10           48.710661                 0     Propriva
# 244     z578         45           30.638696                 0     Ramicane
# 245     z581         45           62.754451                 3    Infubinol
# 246     z795         45           65.741070                 3     Naftisol
# 247     z969         45           73.867845                 4     Naftisol
#
#         Sex  Age_months  Weight (g)
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
drug_treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
drug_treatments
# Out:
# ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# %%
# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = []

# %%
big_four = max_per_treatment_df[max_per_treatment_df["Drug Regimen"].isin(drug_treatments)]
big_four
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       a203         45           67.973419                 2    Infubinol
# 1       a251         45           65.525743                 1    Infubinol
# 3       a275         45           62.999356                 3     Ceftamin
# 6       a411         45           38.407618                 1     Ramicane
# 7       a444         45           43.047543                 0     Ramicane
# ..       ...        ...                 ...               ...          ...
# 238     y769         45           68.594745                 4     Ceftamin
# 239     y793         45           31.896238                 2    Capomulin
# 240     y865         45           64.729837                 3     Ceftamin
# 244     z578         45           30.638696                 0     Ramicane
# 245     z581         45           62.754451                 3    Infubinol
#
#         Sex  Age_months  Weight (g)
# ...

# %%
big_four[big_four['Tumor Volume (mm3)']==big_four['Tumor Volume (mm3)'].max()]
# Out:
#    Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 27     c139         45           72.226731                 2    Infubinol
#
#      Sex  Age_months  Weight (g)
# 27  Male          11          28

# %%
# for loop

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    # Locate the rows which contain mice on each drug and get the tumor volumes
 
    # add subset 

    
for treatment in drug_treatments:
    mice_tumor_vol = big_four.loc[big_four['Drug Regimen']==treatment]['Tumor Volume (mm3)']
    tumor_vol_data.append(mice_tumor_vol)
    
    dfquartiles = mice_tumor_vol.quantile([.25, .5, .75])
    lowerq = dfquartiles[.25]
    upperq = dfquartiles[.75]
    IQR = upperq-lowerq
    lowerbound = lowerq-(1.5*IQR)
    upperbound = upperq+(1.5*IQR)
    
    # Determine outliers using upper and lower bounds
    outlier = mice_tumor_vol.loc[(mice_tumor_vol<lowerbound) | (mice_tumor_vol>upperbound)]
    print(f"{treatment}'s potential outliers: {outlier}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint

# %%
outlier_marker = dict(markerfacecolor = "red", markersize = 10)
plt.boxplot(tumor_vol_data, labels=drug_treatments, flierprops=outlier_marker)
plt.ylabel("Final Tumor Volume (mm3)")

plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
capomulin_data=duplicates_dropped_df.loc[duplicates_dropped_df['Drug Regimen']=="Capomulin"]
capomulin_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
mouse_cap=capomulin_data.loc[capomulin_data['Mouse ID']=="g316"]
mouse_cap
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 1815     g316          0           45.000000                 0    Capomulin
# 1816     g316          5           44.022752                 0    Capomulin
# 1817     g316         10           44.502042                 0    Capomulin
# 1818     g316         15           45.216743                 0    Capomulin
# 1819     g316         20           45.933322                 1    Capomulin
# 1820     g316         25           46.809225                 1    Capomulin
# 1821     g316         30           44.221480                 2    Capomulin
# 1822     g316         35           44.702833                 2    Capomulin
# 1823     g316         40           45.565821                 2    Capomulin
# 1824     g316         45           40.159220                 2    Capomulin
#
#          Sex  Age_months  Weight (g)
# 1815  Female          22          22
# 1816  Female          22          22
# ...

# %%
x = mouse_cap["Timepoint"]
y = mouse_cap["Tumor Volume (mm3)"]
plt.plot(x, y, )
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume(mm3)")
plt.title("Capomulin treatment of mouse g316")
plt.show()

# %%
mouse_cap_data=capomulin_data.groupby("Mouse ID").mean()
mouse_cap_data
# Out:
#           Timepoint  Tumor Volume (mm3)  Metastatic Sites  Age_months  \
# Mouse ID
# b128           22.5           41.963636              0.70         9.0
# b742           22.5           40.083699              0.00         7.0
# f966           10.0           36.505973              0.00        16.0
# g288           22.5           41.990097              0.80         3.0
# g316           22.5           44.613344              1.00        22.0
# i557           22.5           44.805810              0.20         1.0
# i738           22.5           39.141053              0.60        23.0
# j119           22.5           44.465236              0.60         7.0
# j246           17.5           43.216925              0.25        21.0
# l509           22.5           44.434474              1.40        17.0
# l897           22.5           42.507261              0.40        17.0
# m601           22.5           34.847470              0.90        22.0
# ...

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
x = mouse_cap_data["Weight (g)"]
y = mouse_cap_data["Tumor Volume (mm3)"]
plt.scatter(x, y)
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume(mm3)')
plt.title("Capomulin Mouse Weight Vs Average Tumor Volume")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen

x = mouse_cap_data["Weight (g)"]
y = mouse_cap_data["Tumor Volume (mm3)"]
plt.scatter(x,y)
corr_co = x.corr(y)
# print the correlation coefficient
print('The correlation between mouse weight and the average tumor volume is', '%.02f' % corr_co)

plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume(mm3)')
plt.title("Capomulin Mouse Weight Vs Average Tumor Volume")


# calculate the linear regression model
slope, intercept, r_value, p_value, std_err = linregress(x, y)
# print the linear regression equation
print('Linear regression equation: y = {}x + {}'.format(slope, intercept))
# Calculate the linear regression model
slope, intercept, rvalue, pvalue, stderr = linregress(x, y)
regress_values = x * slope + intercept
plt.plot(x, regress_values, 'r')
plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
# Linear regression equation: y = 0.9544396890241049x + 21.552160532685008
